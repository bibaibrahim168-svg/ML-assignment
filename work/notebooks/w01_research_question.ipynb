# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose Lane 2: Refresh / Content Opportunity Scoring because it helps identify which content pages should be reviewed first. This can help prioritize work and support better decisions using data.
# Out:
#   File "/tmp/ipykernel_2347/2738759855.py", line 1
#     I chose Lane 2: Refresh / Content Opportunity Scoring because it helps identify which content pages should be reviewed first. This can help prioritize work and support better decisions using data.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision:
The project helps decide which content pages should be reviewed first.

Who acts on it?
A content reviewer or SEO team uses the ranked list to decide which pages to update.

Cost of a wrong recommendation:
If a page is incorrectly recommended, time may be wasted reviewing a page that does not need changes. If an important page is missed, the website may lose traffic and improvement opportunities

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Load the starter dataset
# !git clone https://github.com/bibaibrahim168-svg/ML-assignment.git

import pandas as pd

df = pd.read_csv("/content/ML-assignment/data/raw/content_refresh_anonymized.csv")

# 1. Dataset size
print("Rows and Columns:", df.shape)

# 2. Number of missing values
print("\nMissing values:")
print(df.isnull().sum().sum())

# 3. Number of features (columns)
print("\nNumber of features:")
print(len(df.columns))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This project provides decision support based on observed data patterns. It can help identify which pages may need to be reviewed first. However, it cannot prove that updating a page will improve performance, and it cannot predict Google's ranking with certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
